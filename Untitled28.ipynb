# %% [markdown]
# <a href="https://colab.research.google.com/github/fhiwigs/3x-ui/blob/main/Untitled28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("/content/txt.txt", "w", encoding="utf-8") as f:
    f.write("Hello from Google Colab!")

print("فایل ساخته شد: /content/txt.txt")
# Out:
# فایل ساخته شد: /content/txt.txt
